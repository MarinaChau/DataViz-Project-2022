# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaChau/DataViz-Project-2022/blob/main/Projet_Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is the environmental impact of my plate?

# %% [markdown]
# ## Questions subsidiaires
#
# * Quelle est la part de CO2 de la viande dans mon assiette?
# * Faut-il choisir un produit conventionnel ou biologique?

# %% [markdown]
# Link to visualization library : `https://www.intellspot.com/python-visualization-tools/`

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Download the different dataset

# !wget https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3.0.1_vf.xlsm
# !wget https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-synthese/raw
# !wget https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-detail-etape/raw
# !wget https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-detail-ingredient/raw
# Out:
# --2022-06-21 11:44:43--  https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3.0.1_vf.xlsm
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3.0.1_vf.xlsm [following]
# --2022-06-21 11:44:44--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3.0.1_vf.xlsm
# Reusing existing connection to koumoul.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5610747 (5.4M) [application/vnd.ms-excel.sheet.macroenabled.12]
# Saving to: ‘AGRIBALYSE3.0.1_vf.xlsm.2’
#
# AGRIBALYSE3.0.1_vf. 100%[===================>]   5.35M  1.93MB/s    in 2.8s
#
# 2022-06-21 11:44:47 (1.93 MB/s) - ‘AGRIBALYSE3.0.1_vf.xlsm.2’ saved [5610747/5610747]
#
# --2022-06-21 11:44:47--  https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-synthese/raw
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw [following]
# --2022-06-21 11:44:47--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw
# Reusing existing connection to koumoul.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 927255 (906K) [text/csv]
# Saving to: ‘raw.3’
#
# raw.3               100%[===================>] 905.52K  1.63MB/s    in 0.5s
#
# 2022-06-21 11:44:48 (1.63 MB/s) - ‘raw.3’ saved [927255/927255]
#
# --2022-06-21 11:44:48--  https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-detail-etape/raw
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-detail-etape/raw [following]
# --2022-06-21 11:44:48--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-detail-etape/raw
# Reusing existing connection to koumoul.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3090950 (2.9M) [text/csv]
# Saving to: ‘raw.4’
#
# raw.4               100%[===================>]   2.95M  1.94MB/s    in 1.5s
#
# 2022-06-21 11:44:50 (1.94 MB/s) - ‘raw.4’ saved [3090950/3090950]
#
# --2022-06-21 11:44:50--  https://koumoul.com/s/data-fair/api/v1/datasets/agribalyse-detail-ingredient/raw
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-detail-ingredient/raw [following]
# --2022-06-21 11:44:51--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-detail-ingredient/raw
# Reusing existing connection to koumoul.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1996561 (1.9M) [text/csv]
# Saving to: ‘raw.5’
#
# raw.5               100%[===================>]   1.90M  2.00MB/s    in 1.0s
#
# 2022-06-21 11:44:52 (2.00 MB/s) - ‘raw.5’ saved [1996561/1996561]

# %%
# !wget https://www.data.gouv.fr/fr/datasets/r/83289c89-8134-4426-8959-eccad79f8873
# Out:
# --2022-06-21 11:44:52--  https://www.data.gouv.fr/fr/datasets/r/83289c89-8134-4426-8959-eccad79f8873
# Resolving www.data.gouv.fr (www.data.gouv.fr)... 37.59.183.93
# Connecting to www.data.gouv.fr (www.data.gouv.fr)|37.59.183.93|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw [following]
# --2022-06-21 11:44:52--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 927255 (906K) [text/csv]
# Saving to: ‘83289c89-8134-4426-8959-eccad79f8873’
#
# 83289c89-8134-4426- 100%[===================>] 905.52K  1.08MB/s    in 0.8s
#
# 2022-06-21 11:44:54 (1.08 MB/s) - ‘83289c89-8134-4426-8959-eccad79f8873’ saved [927255/927255]

# %%
df_synthese = pd.read_csv("/content/dataset_synth.csv")

# %%
df_synthese.head()
# Out:
#   Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0    13712        13712  fruits, légumes, légumineuses et oléagineux
# 1    13713        13713  fruits, légumes, légumineuses et oléagineux
# 2    13714        13714  fruits, légumes, légumineuses et oléagineux
# 3    13715        13715  fruits, légumes, légumineuses et oléagineux
# 4    13000        13000  fruits, légumes, légumineuses et oléagineux
#
#   Sous-groupe d'aliment                      Nom du Produit en Français  \
# 0                fruits      Abricot au sirop léger, appertisé, égoutté
# 1                fruits  Abricot au sirop léger, appertisé, non égoutté
# 2                fruits            Abricot au sirop, appertisé, égoutté
# 3                fruits        Abricot au sirop, appertisé, non égoutté
# 4                fruits                         Abricot, dénoyauté, cru
#
#                                       LCI Name            Saisonnalité  \
# 0      Apricot, canned in light syrup, drained  mix de consommation FR
# 1  Apricot, canned in light syrup, not drained  mix de consommation FR
# 2           Apricot, in syrup, canned, drained  mix de consommation FR
# 3       Apricot, in syrup, canned, not drained  mix de consommation FR
# 4                         Apricot, pitted, raw  mix de consommation FR
#
#    Transport par avion (1 : par avion)          Livraison  \
# 0                                    0  Ambiant (moyenne)
# 1                                    0  Ambiant (moyenne)
# 2                                    0  Ambiant (moyenne)
# 3                                    0  Ambiant (moyenne)
# 4                                    0  Ambiant (moyenne)
#
#   Matériau d'emballage  ... Particules (E-06 disease inc./kg de produit)  \
# 0                Acier  ...                                     0.096413
# 1                Acier  ...                                     0.059314
# 2                Acier  ...                                     0.096413
# 3                Acier  ...                                     0.059314
# 4                 LPDE  ...                                     0.061462
#
#    Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 0                                           0.009301
# 1                                           0.005726
# 2                                           0.009301
# 3                                           0.005726
# 4                                           0.007254
#
#    Eutrophisation terreste (mol N eq/kg de produit)  \
# 0                                          0.031766
# 1                                          0.019499
# 2                                          0.031766
# 3                                          0.019499
# 4                                          0.025954
#
#    Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 0                                           0.410555
# 1                                           0.235366
# 2                                           0.410555
# 3                                           0.235366
# 4                                           0.204244
#
#    Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 0                                           1.502775
# 1                                           0.797791
# 2                                           1.502775
# 3                                           0.797791
# 4                                           0.943669
#
#    Utilisation du sol (Pt/kg de produit)  \
# 0                              44.823181
# 1                              27.901738
# 2                              44.823181
# 3                              27.901738
# 4                              43.838644
#
#    Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 0                                          62.195218
# 1                                          36.285914
# 2                                          62.195218
# 3                                          36.285914
# 4                                          41.957928
#
#    Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 0                                           1.630637
# 1                                           1.010960
# 2                                           1.630637
# 3                                           1.010960
# 4                                           1.412878
#
#    Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 0                                          47.237697
# 1                                          29.397697
# 2                                          47.237697
# 3                                          29.397697
# 4                                          17.123820
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 0                                           2.938064
# 1                                           1.823726
# 2                                           2.938064
# 3                                           1.823726
# 4                                           2.173328
#
# [5 rows x 27 columns]

# %%
#

# %%
df_synthese.shape  # 27 features and 2479 products
# Out:
# (2479, 27)
