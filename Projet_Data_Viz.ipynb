# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaChau/DataViz-Project-2022/blob/main/Projet_Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is the environmental impact of my plate?

# %% [markdown]
# ## Questions subsidiaires
#
# * Quelle est la part de CO2 de la viande dans mon assiette?
# * Faut-il choisir un produit conventionnel ou biologique?
#
# **Agribalyse utilise le DQR score pour noter les produits:**
#
# Une note de qualité - le Data Quality Ratio (DQR) - de 1, très bon, à 5, très mauvais - est associée à chaque produit agricole et alimentaire pour lequel Agribalyse fournit des inventaires de cycle de vie et des indicateurs d’impacts. La Commission Européenne recommande de la prudence dans l’utilisation des données avec des DQR supérieurs à 3. Dans la base de données AGRIBALYSE, 67 % des données ont un DQR jugé bon ou très bon (1 à 3).

# %% [markdown]
# Link to visualization library : `https://www.intellspot.com/python-visualization-tools/`

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# plotly
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot, plot
from plotly.subplots import make_subplots
## fixer le theme
import plotly.io as pio
pio.templates.default = 'ggplot2'

# scikit-learn
## Métriques
from sklearn.metrics import silhouette_score
## Clustering
from sklearn.cluster import KMeans

# yellowbrick
## Clustering
from yellowbrick.cluster import SilhouetteVisualizer

# %%
# Download the different dataset

# !wget https://www.data.gouv.fr/fr/datasets/r/83289c89-8134-4426-8959-eccad79f8873 # Summary of the dataset
# !wget https://www.data.gouv.fr/fr/datasets/r/e822439e-e088-4f9f-b4d9-6fe10124a376 # Label description

# !wget https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3_partie%20agriculture_conv.xlsx # raw data from industrial agriculture
# !wget https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3_partie%20agriculture_bio.xlsx # raw data from organic agriculture
# Out:
# --2022-06-21 12:01:44--  https://www.data.gouv.fr/fr/datasets/r/83289c89-8134-4426-8959-eccad79f8873
# Resolving www.data.gouv.fr (www.data.gouv.fr)... 37.59.183.93
# Connecting to www.data.gouv.fr (www.data.gouv.fr)|37.59.183.93|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw [following]
# --2022-06-21 12:01:44--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/raw
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 927255 (906K) [text/csv]
# Saving to: ‘83289c89-8134-4426-8959-eccad79f8873.3’
#
# 83289c89-8134-4426- 100%[===================>] 905.52K  1.33MB/s    in 0.7s
#
# 2022-06-21 12:01:45 (1.33 MB/s) - ‘83289c89-8134-4426-8959-eccad79f8873.3’ saved [927255/927255]
#
# --2022-06-21 12:01:46--  https://www.data.gouv.fr/fr/datasets/r/e822439e-e088-4f9f-b4d9-6fe10124a376
# Resolving www.data.gouv.fr (www.data.gouv.fr)... 37.59.183.93
# Connecting to www.data.gouv.fr (www.data.gouv.fr)|37.59.183.93|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://data.ademe.fr/datasets/agribalyse-synthese [following]
# --2022-06-21 12:01:46--  https://data.ademe.fr/datasets/agribalyse-synthese
# Resolving data.ademe.fr (data.ademe.fr)... 51.75.192.4
# Connecting to data.ademe.fr (data.ademe.fr)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 751966 (734K) [text/html]
# Saving to: ‘e822439e-e088-4f9f-b4d9-6fe10124a376’
#
# e822439e-e088-4f9f- 100%[===================>] 734.34K  1.32MB/s    in 0.5s
#
# 2022-06-21 12:01:47 (1.32 MB/s) - ‘e822439e-e088-4f9f-b4d9-6fe10124a376’ saved [751966/751966]
#
# --2022-06-21 12:01:48--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3_partie%20agriculture_conv.xlsx
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1342779 (1.3M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘AGRIBALYSE3_partie agriculture_conv.xlsx.1’
#
# AGRIBALYSE3_partie  100%[===================>]   1.28M  1.58MB/s    in 0.8s
#
# 2022-06-21 12:01:49 (1.58 MB/s) - ‘AGRIBALYSE3_partie agriculture_conv.xlsx.1’ saved [1342779/1342779]
#
# --2022-06-21 12:01:49--  https://koumoul.com/data-fair/api/v1/datasets/agribalyse-synthese/metadata-attachments/AGRIBALYSE3_partie%20agriculture_bio.xlsx
# Resolving koumoul.com (koumoul.com)... 51.75.192.4
# Connecting to koumoul.com (koumoul.com)|51.75.192.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1317839 (1.3M) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘AGRIBALYSE3_partie agriculture_bio.xlsx.1’
#
# AGRIBALYSE3_partie  100%[===================>]   1.26M  1.55MB/s    in 0.8s
#
# 2022-06-21 12:01:50 (1.55 MB/s) - ‘AGRIBALYSE3_partie agriculture_bio.xlsx.1’ saved [1317839/1317839]

# %%
df_synthese = pd.read_csv("/content/dataset_synth.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_synthese.head()
# Out:
#   Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0    13712        13712  fruits, légumes, légumineuses et oléagineux
# 1    13713        13713  fruits, légumes, légumineuses et oléagineux
# 2    13714        13714  fruits, légumes, légumineuses et oléagineux
# 3    13715        13715  fruits, légumes, légumineuses et oléagineux
# 4    13000        13000  fruits, légumes, légumineuses et oléagineux
#
#   Sous-groupe d'aliment                      Nom du Produit en Français  \
# 0                fruits      Abricot au sirop léger, appertisé, égoutté
# 1                fruits  Abricot au sirop léger, appertisé, non égoutté
# 2                fruits            Abricot au sirop, appertisé, égoutté
# 3                fruits        Abricot au sirop, appertisé, non égoutté
# 4                fruits                         Abricot, dénoyauté, cru
#
#                                       LCI Name            Saisonnalité  \
# 0      Apricot, canned in light syrup, drained  mix de consommation FR
# 1  Apricot, canned in light syrup, not drained  mix de consommation FR
# 2           Apricot, in syrup, canned, drained  mix de consommation FR
# 3       Apricot, in syrup, canned, not drained  mix de consommation FR
# 4                         Apricot, pitted, raw  mix de consommation FR
#
#    Transport par avion (1 : par avion)          Livraison  \
# 0                                    0  Ambiant (moyenne)
# 1                                    0  Ambiant (moyenne)
# 2                                    0  Ambiant (moyenne)
# 3                                    0  Ambiant (moyenne)
# 4                                    0  Ambiant (moyenne)
#
#   Matériau d'emballage  ... Particules (E-06 disease inc./kg de produit)  \
# 0                Acier  ...                                     0.096413
# 1                Acier  ...                                     0.059314
# 2                Acier  ...                                     0.096413
# 3                Acier  ...                                     0.059314
# 4                 LPDE  ...                                     0.061462
#
#    Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 0                                           0.009301
# 1                                           0.005726
# 2                                           0.009301
# 3                                           0.005726
# 4                                           0.007254
#
#    Eutrophisation terreste (mol N eq/kg de produit)  \
# 0                                          0.031766
# 1                                          0.019499
# 2                                          0.031766
# 3                                          0.019499
# 4                                          0.025954
#
#    Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 0                                           0.410555
# 1                                           0.235366
# 2                                           0.410555
# 3                                           0.235366
# 4                                           0.204244
#
#    Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 0                                           1.502775
# 1                                           0.797791
# 2                                           1.502775
# 3                                           0.797791
# 4                                           0.943669
#
#    Utilisation du sol (Pt/kg de produit)  \
# 0                              44.823181
# 1                              27.901738
# 2                              44.823181
# 3                              27.901738
# 4                              43.838644
#
#    Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 0                                          62.195218
# 1                                          36.285914
# 2                                          62.195218
# 3                                          36.285914
# 4                                          41.957928
#
#    Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 0                                           1.630637
# 1                                           1.010960
# 2                                           1.630637
# 3                                           1.010960
# 4                                           1.412878
#
#    Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 0                                          47.237697
# 1                                          29.397697
# 2                                          47.237697
# 3                                          29.397697
# 4                                          17.123820
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 0                                           2.938064
# 1                                           1.823726
# 2                                           2.938064
# 3                                           1.823726
# 4                                           2.173328
#
# [5 rows x 27 columns]

# %%
df_synthese.isna().sum() # No null
# Out:
# Code AGB                                                                    0
# Code CIQUAL                                                                 0
# Groupe d'aliment                                                            0
# Sous-groupe d'aliment                                                       0
# Nom du Produit en Français                                                  0
# LCI Name                                                                    0
# Saisonnalité                                                                0
# Transport par avion (1 : par avion)                                         0
# Livraison                                                                   0
# Matériau d'emballage                                                        0
# Préparation                                                                 0
# DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)           0
# Score unique EF (mPt/kg de produit)                                         0
# Changement climatique (kg CO2 eq/kg de produit)                             0
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)       0
# Rayonnements ionisants (kBq U-235 eq/kg de produit)                         0
# Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)            0
# Particules (E-06 disease inc./kg de produit)                                0
# Acidification terrestre et eaux douces (mol H+ eq/kg de produit)            0
# Eutrophisation terreste (mol N eq/kg de produit)                            0
# Eutrophisation eaux douces (E-03 kg P eq/kg de produit)                     0
# Eutrophisation marine (E-03 kg N eq/kg de produit)                          0
# Utilisation du sol (Pt/kg de produit)                                       0
# Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)    0
# Épuisement des ressources eau (m3 depriv./kg de produit)                    0
# Épuisement des ressources énergétiques (MJ/kg de produit)                   0
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)            0
# dtype: int64

# %%
df = df_synthese.drop_duplicates()

# %%
# We're going to drop "Code AGB" and "Code CIQUAL"
df = df.drop(['Code AGB', 'Code CIQUAL', 'LCI Name'], axis=1)

# %%
df.shape
# Out:
# (2479, 27)

# %%
df["Groupe d'aliment"].value_counts()
# Out:
# viandes, œufs, poissons                        636
# fruits, légumes, légumineuses et oléagineux    423
# produits céréaliers                            375
# entrées et plats composés                      281
# lait et produits laitiers                      220
# boissons                                       219
# aides culinaires et ingrédients divers         158
# matières grasses                                56
# produits sucrés                                 53
# aliments infantiles                             33
# glaces et sorbets                               25
# Name: Groupe d'aliment, dtype: int64

# %%
df.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'Saisonnalité',
#        'Transport par avion (1 : par avion)', 'Livraison',
#        'Matériau d'emballage', 'Préparation',
#        'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)',
#        'Score unique EF (mPt/kg de produit)',
#        'Changement climatique (kg CO2 eq/kg de produit)',
#        'Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)',
#        'Rayonnements ionisants (kBq U-235 eq/kg de produit)',
#        'Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)',
#        'Particules (E-06 disease inc./kg de produit)',
#        'Acidification terrestre et eaux douces (mol H+ eq/kg de produit)',
#        'Eutrophisation terreste (mol N eq/kg de produit)',
#        'Eutrophisation eaux douces (E-03 kg P eq/kg de produit)',
#        'Eutrophisation marine (E-03 kg N eq/kg de produit)',
#        'Utilisation du sol (Pt/kg de produit)',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)',
#        'Épuisement des ressources eau (m3 depriv./kg de produit)',
#        'Épuisement des ressources énergétiques (MJ/kg de produit)',
#        'Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit
.0,2.89,2.15,2.78,2.78,2.7,2.98,3.68,3.68,3.56,2.24,3.52,3.74,3.95,2.92,2.55,2.5,2.82,2.97,2.32,2.86,2.66,2.55,2.98,2.98,3.71,4.03,3.71,3.71,3.71,3.71,4.03,4.03,4.03,4.03,4.03,3.71,3.71,3.71,3.71,3.33,4.03,4.03,3.95,2.2,2.49,2.49,2.49,2.63,2.65,2.49,2.47,2.63,2.65,2.45,2.8,2.47,2.47,3.18,2.38,2.6,2.24,2.66,2.67,3.18,3.53,3.89,3.89,3.89,2.13,1.84,1.96,3.07,2.63,2.65,2.45,4.36,3.01,3.01,2.31,2.6,2.6,2.39,3.44,1.97,3.57,3.57,3.57,2.47,2.49,2.58,2.93,2.45,2.45,2.45,2.99,2.99,2.99,2.99,2.99,2.99,2.99,2.29,2.99,2.99,2.99,2.47,3.34,3.34,3.34,3.34,2.53,2.53,2.51,3.02,2.63,2.13,2.6,3.0,2.6,3.1,2.6,3.0,3.1,3.19,2.42,2.6,3.0,2.55,2.86,2.6,2.6,2.86,2.38,3.05,2.09,2.75,2.64,2.95,2.13,2.86,2.7,3.75,2.89,2.89,2.89,2.89,2.89,2.49,3.45,2.41,3.01,2.46,2.7,2.49,2.19,2.68,3.56,2.65,2.68,2.29,2.61,2.97,2.63,2.65,2.21,2.24,3.05,3.05,2.47,2.59,2.61,2.63,3.01,2.6,2.6,2.6,2.6,2.6,1.98,1.98,1.98,1.98,1.81,2.53,2.53,2.53,2.91,2.51,2.96,2.91,3.05,2.36,2.36,3.16,3.55,2.04,3.16,3.64,2.2,2.51,2.47,2.85,2.9,3.43,3.68,2.52,3.75,3.75,2.59,3.64,2.24,3.48,3.11,2.51,2.55,2.51,2.6,2.38,2.89,2.38,2.43,2.92,2.95,2.92,2.91,3.55,3. ...

# %% [markdown]
# * median = 2.76 : la moitié des DQR sont inférieures ou égale à 2.76.
# * Les notes DQR inférieures strictement à 3 sont considérées comme bons ou très bons : cela consitituent environ de 67% des valeurs.
# * NB : pour la valeur 3, ici elle est apparemment considérée comme fiable, et ici ce n'est pas le cas. J'ai considéré ici 3 comme peu fiable. Seule 22 produits ont un DQR égal à 3.
# * Ils semblent qu'ils y aient des groupes de DQR (voir "5e niveau d'exploration").

# %%
# nombre de produits ayant un DQR=3
len(df[df_synthese.loc[:,target]==3])
# Out:
# 22

# %%
# nombre de sous-groupes
df.loc[:,"Sous-groupe d'aliment"].nunique()
# Out:
# 58

# %%
fig = px.histogram(df, y="Sous-groupe d'aliment", 
                  title="Répartition des différents sous-groupes d'aliment", orientation ="h",
                  color_discrete_sequence=px.colors.qualitative.Vivid)
fig.update_yaxes(categoryorder="total ascending")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d645b081-f1d7-42f6-9b93-76dbdb44ce57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d645b081-f1d7-42f6-9b93-76dbdb44ce57")) {                    Plotly.newPlot(                        "d645b081-f1d7-42f6-9b93-76dbdb44ce57",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"count=%{x}<br>Sous-groupe d'aliment=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"xaxis":"x","y":["fruits","fruits","fruits","fruits","fruits","fruits","produits \u00e0 base de poissons et produits de la mer","algues","viandes cuites","viandes crues","viandes crues","viandes cuites","viandes crues","viandes cuites","viandes crues","viandes cuites","viandes crues","viandes crues","viandes cuites","viandes cuites","viandes cuites","viandes crues","viandes cuites","viandes cuites","viandes crues","viandes cuites","viandes cuites","herbes","herbes","boisson alcoolis\u00e9es","plats compos\u00e9s","fruits \u00e0 coque et graines ol\u00e9agineuses","fruits \u00e0 coque et graines ol\u00e9agineuses","fruits \u00e0 coque et graines ol\u00e9agineuses","p\u00e2tes, riz et c\u00e9r\u00e9ales","farines et p\u00e2tes \u00e0 tarte","fruits","fruits","fruits","fruits","fruits","produits \u00e0 base de poissons et produits de la mer","poissons crus","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","charcuteries","charcuteries","charcuteries","charcuteries","charcuteries","charcuteries","charcuteries","herbes","algues","boisson alcoolis\u00e9es","fruits \u00e0 coque et graines ol\u00e9agineuses","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","algues","fromages","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","p\u00e2tes, riz et c\u00e9r\u00e9ales","g\u00e2teaux et p\u00e2tisseries","pains et viennoiseries","g\u00e2teaux et p\u00e2tisseries","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","pommes de terre et autres tubercules","fruits","fruits","poissons crus","poissons crus","poissons crus","poissons cuits","poissons crus","poissons crus","chocolats et produits \u00e0 base de chocolat","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","chocolats et produits \u00e0 base de chocolat","chocolats et produits \u00e0 base de chocolat","chocolats et produits \u00e0 base de chocolat","chocolats et produits \u00e0 base de chocolat","glaces","chocolats et produits \u00e0 base de chocolat","chocolats et produits \u00e0 base de chocolat","chocolats et produits \u00e0 base de chocolat","ingr\u00e9dients divers","ingr\u00e9dients divers","herbes","herbes","fromages","g\u00e2teaux et p\u00e2tisseries","produits \u00e0 base de poissons et produits de la mer","plats compos\u00e9s","feuillet\u00e9es et autres entr\u00e9es","g\u00e2teaux et p\u00e2tisseries","g\u00e2teaux et p\u00e2tisseries","g\u00e2teaux et p\u00e2tisseries","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","l\u00e9gumes","beurres","beurres","beurres","beurres","beurres","beurres","beurres","fruits \u00e0 coque et graines ol\u00e9agineuses","huiles et graisses v\u00e9g\u00e9tales","ingr\u00e9dients divers","boisson alcoolis\u ...

# %% [markdown]
# * Le nombre de catégories est plus important : il y a 58 sous-groupes.
# * A cette échelle, avec ce nombre de catégories :
# ** chaque catégorie est assez peu représentée : le 1e sous-groupe ne représente même pas 10% des produits
# plus de la moitié des sous-catégories représentent moins de 1% des produits.
# ** Regardons les sous-groupes qui contiennent au moins 100 produits (le diagramme ci-dessous précise le lien entre "Groupe d'aliment" et "Sous-groupe d'aliment") :
# * Le premier sous-groupe est "légumes", qui appartient au 2e groupe "fruits, légumes, légumineuses et oléagineux", et non pas au 1e groupe
# * Les 2e et 3e sous-groupes sont "charcuteries" et "viandes crues", qui appartiennent au 1e groupe "viandes, œufs, poissons".
# * 4e sous-groupe : "céréales de petit-déjeuner et biscuits"
# * Moins attendus, les sous-groupes "plats composés" et "fromages" appartiennent aux 4e groupe "entrées et plats composés" et au 5e groupe "lait et produits laitiers".
# * Le 7e sous-groupe est "viandes cuites" du 1e groupe.

# %%
fig = px.icicle(df,
                path=[px.Constant("Tous les produits"), "Groupe d'aliment", "Sous-groupe d'aliment"], 
                title="Relation entre 'Groupe d'aliment' et 'Sous-groupe d'aliment'",
                color_discrete_sequence=px.colors.qualitative.Vivid
             )
fig.update_traces(root_color='lightgrey')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9
/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/fruits","Ambiant (moyenne)/lait et produits laitiers/laits","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/l\u00e9gumes","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/l\u00e9gumineuses","Ambiant (moyenne)/viandes, \u0153ufs, poissons/produits \u00e0 base de poissons et produits de la mer","Ambiant (moyenne)/produits c\u00e9r\u00e9aliers/p\u00e2tes, riz et c\u00e9r\u00e9ales","Ambiant (moyenne)/aides culinaires et ingr\u00e9dients divers/sauces","Ambiant (moyenne)/produits sucr\u00e9s/sucres, miels et assimil\u00e9s","Ambiant (moyenne)/viandes, \u0153ufs, poissons/\u0153ufs","Ambiant (moyenne)/aides culinaires et ingr\u00e9dients divers","Ambiant (moyenne)/boissons","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","Ambiant (moyenne)/lait et produits laitiers","Ambiant (moyenne)/produits c\u00e9r\u00e9aliers","Ambiant (moyenne)/produits sucr\u00e9s","Ambiant (moyenne)/viandes, \u0153ufs, poissons","Ambiant (moyenne)"],"labels":["boisson alcoolis\u00e9es","boissons sans alcool","chocolats et produits \u00e0 base de chocolat","condiments","confiseries non chocolat\u00e9es","eaux","farines et p\u00e2tes \u00e0 tarte","fruits","laits","l\u00e9gumes","l\u00e9gumineuses","produits \u00e0 base de poissons et produits de la mer","p\u00e2tes, riz et c\u00e9r\u00e9ales","sauces","sucres, miels et assimil\u00e9s","\u0153ufs","aides culinaires et ingr\u00e9dients divers","boissons","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","lait et produits laitiers","produits c\u00e9r\u00e9aliers","produits sucr\u00e9s","viandes, \u0153ufs, poissons","Ambiant (moyenne)"],"name":"","parents":["Ambiant (moyenne)/boissons","Ambiant (moyenne)/boissons","Ambiant (moyenne)/produits sucr\u00e9s","Ambiant (moyenne)/aides culinaires et ingr\u00e9dients divers","Ambiant (moyenne)/produits sucr\u00e9s","Ambiant (moyenne)/boissons","Ambiant (moyenne)/produits c\u00e9r\u00e9aliers","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","Ambiant (moyenne)/lait et produits laitiers","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","Ambiant (moyenne)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","Ambiant (moyenne)/viandes, \u0153ufs, poissons","Ambiant (moyenne)/produits c\u00e9r\u00e9aliers","Ambiant (moyenne)/aides culinaires et ingr\u00e9dients divers","Ambiant (moyenne)/produits sucr\u00e9s","Ambiant (moyenne)/viandes, \u0153ufs, poissons","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)",""],"values":[20,30,30,5,9,90,20,85,16,107,19,18,16,1,7,9,6,140,211,16,36,46,27,482],"t ...

# %%
fig = px.icicle(df.loc[df.Livraison=='Ambiant (long)'],
          path=['Livraison', "Groupe d'aliment", "Sous-groupe d'aliment"],
               color_discrete_sequence=px.colors.qualitative.Vivid,
                title="Livraison 'Ambiant (long)' : groupes et sous-groupes d'aliments concernés"
               )
fig.update_traces(root_color='lightgrey')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2dda763e-6b79-4f78-9f60-22a830791769" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dda763e-6b79-4f78-9f60-22a830791769")) {                    Plotly.newPlot(                        "2dda763e-6b79-4f78-9f60-22a830791769",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Ambiant (long)/aides culinaires et ingr\u00e9dients divers/aides culinaires","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/algues","Ambiant (long)/boissons/boissons sans alcool","Ambiant (long)/produits c\u00e9r\u00e9aliers/c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","Ambiant (long)/aliments infantiles/c\u00e9r\u00e9ales et biscuits infantiles","Ambiant (long)/aliments infantiles/desserts infantiles","Ambiant (long)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/fruits","Ambiant (long)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/fruits \u00e0 coque et graines ol\u00e9agineuses","Ambiant (long)/produits c\u00e9r\u00e9aliers/g\u00e2teaux et p\u00e2tisseries","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/herbes","Ambiant (long)/mati\u00e8res grasses/huiles de poissons","Ambiant (long)/mati\u00e8res grasses/huiles et graisses v\u00e9g\u00e9tales","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/ingr\u00e9dients divers","Ambiant (long)/lait et produits laitiers/laits","Ambiant (long)/aliments infantiles/laits et boissons infantiles","Ambiant (long)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/l\u00e9gumes","Ambiant (long)/aliments infantiles/petits pots sal\u00e9s et plats infantiles","Ambiant (long)/entr\u00e9es et plats compos\u00e9s/plats compos\u00e9s","Ambiant (long)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/pommes de terre et autres tubercules","Ambiant (long)/produits c\u00e9r\u00e9aliers/p\u00e2tes, riz et c\u00e9r\u00e9ales","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/sauces","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/sels","Ambiant (long)/entr\u00e9es et plats compos\u00e9s/soupes","Ambiant (long)/aides culinaires et ingr\u00e9dients divers/\u00e9pices","Ambiant (long)/aides culinaires et ingr\u00e9dients divers","Ambiant (long)/aliments infantiles","Ambiant (long)/boissons","Ambiant (long)/entr\u00e9es et plats compos\u00e9s","Ambiant (long)/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","Ambiant (long)/lait et produits laitiers","Ambiant (long)/mati\u00e8res grasses","Ambiant (long)/produits c\u00e9r\u00e9aliers","Ambiant (long)"],"labels":["aides culinaires","algues","boissons sans alcool","c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","c\u00e9r\u00e9ales et biscuits infantiles","desserts infantiles","fruits","fruits \u00e0 coque et graines ol\u00e9agineuses","g\u00e2teaux et p\u00e2tisseries","herbes","huiles de poissons","huiles et graisses v\u00e9g\u00e9tales","ingr\u00e9dients divers","laits","laits et boissons infantiles","l\u00e9gumes","petits pots sal\u00e9s et plats infantiles","plats compos\u00e9s","pommes de terre et autres tubercules","p\u00e2tes, riz et c\u00e9r\u00e9ales","sauces","sels","soupes","\u00e9pices","aides culinaires et ingr\u00e9dients divers","aliments infantiles","boissons","entr\u00e9es et plats compos\u00e9s","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","lait et produits laitiers","mati\u00e8res grasses","produits c\u00e9r\u00e9aliers","Ambiant (long)"],"name":"","parents":["Ambiant (long)/aides culinaires et ingr\u00e9dients divers","Ambiant (long)/aides culinaires et ingr\u00e9dients divers","Ambiant (long)/bo ...

# %% [markdown]
# * Près de la moitié des livraisons 'Glacé' sont du groupe d'aliment 'viandes, oeufs, poissons', qui joue encore un rôle prépondérant.
# * Pour les livraison "Ambiant (moyenne)", "fruits, légumes, légumineuses et oléagineux" et "boissons" sont les groupes prépondérants.
# * Pour les livraison "Ambiant (long)", "produits céréaliers" est le groupe prépondérant.
# *Notons la relation d'ordre entre 'Livraison' et 'Groupe d'aliment' :
#  * 'Glacé' / 'viandes, oeufs, poissons'
#  * "Ambiant (moyenne)" / "fruits, légumes, légumineuses et oléagineux"
#  * "Ambiant (long)" / "produits céréaliers".

# %% [markdown]
# ### Matériau d'emballage

# %%
fig = px.histogram(df, x="Matériau d'emballage", 
                    title="Répartition des différents materiau d'emballage", 
                  #  histnorm='probability',
                    color_discrete_sequence=px.colors.qualitative.Vivid)
fig.update_xaxes(categoryorder="total descending")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e50f5e58-91a5-437f-ab73-5c0275ae4616" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e50f5e58-91a5-437f-ab73-5c0275ae4616")) {                    Plotly.newPlot(                        "e50f5e58-91a5-437f-ab73-5c0275ae4616",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Mat\u00e9riau d'emballage=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Acier","Acier","Acier","Acier","LPDE","LPDE","PS","LPDE","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","Verre","Pas d'emballage","Verre","PP","LPDE","LPDE","LPDE","LPDE","Carton","Acier","Acier","Acier","Acier","Pas d'emballage","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","LPDE","LPDE","Verre","LPDE","Acier","Acier","Pas d'emballage","PP","Acier","LPDE","LPDE","LPDE","Acier","Pas d'emballage","PP","Pas d'emballage","Pas d'emballage","Pas d'emballage","PP","Pas d'emballage","LPDE","PS","Papier","PS","Pas d'emballage","Acier","Pas d'emballage","PP","Pas d'emballage","LPDE","PS","PS","PS","PP","PS","PS","Carton","Carton","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","Carton","Carton","LPDE","Carton","PP","Carton","Carton","Carton","Carton","Carton","LPDE","Verre","LPDE","PS","PS","PP","PS","PS","PS","PS","Pas d'emballage","PP","Pas d'emballage","LPDE","PP","PP","PP","PP","PP","PP","PP","V (PVC)","Bouteille PET","Carton","Verre","Verre","Verre","Verre","Verre","Verre","Verre","Carton","Carton","Carton","Carton","Carton","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","Carton","PS","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","PP","LPDE","LPDE","PP","LPDE","PP","PP","LPDE","LPDE","PS","PP","PP","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","PS","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","PS","PS","PS","PS","PS","PS","Carton","Carton","Carton","D\u00e9j\u00e0 emball\u00e9 - PET","D\u00e9j\u00e0 emball\u00e9 - PET","D\u00e9j\u00e0 emball\u00e9 - PET","Bouteille PETE","Carton","Carton","Carton","Carton","Bouteille PETE","Bouteille PETE","Bouteille PETE","HPDE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","D\u00e9j\u00e0 emball\u00e9 - PET","D\u00e9j\u00e0 emball\u00e9 - PET","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","HPDE","HPDE","HPDE","HPDE","HPDE","HPDE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","Bouteille PETE","D\u00e9j\u00e0 emball\u00e9 - PET","Bouteille PETE","Carton","LPDE","LPDE","LPDE","LPDE","PS","Carton","Carton","Carton","PS","PS","PS","Carton","LPDE","LPDE","PP","LPDE","PP","PS","D\u00e9j\u00e0 emball\u00e9 - PP/PE","PS","PS","PS","PS","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","PS","PS","PP","PS","PS","PS","Pas d'emballage","PP","PP","LPDE","LPDE","PS","PS","PP","PS","PS","Carton","PS","PP","PP","LPDE","LPDE","LPDE","LPDE","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","Carton","PS","LPDE","Carton","LPDE","PS","PS","PS","PS"," ...

# %% [markdown]
# Signification des Sigles
# (source : internet)
#
# * PS = Polystyrène (plastique)
# * LDPE = polyéthylène à basse densité (plastique)
# * PP = polypropylène (plastique)
# * PET = PETE = polyéthylène téréphtalate (plastique)
# * PVC = chlorure de polyvinyle (plastique)
# * HPDE = High-density polyethylene (plastique)
# * PE = polyéthylène (plastique)

# %%
plastique_emballage = ['PS', 'LPDE', 'PP', 'Déjà emballé - PET', 'V (PVC)', 'Bouteille PETE',  'HPDE',
                       'Déjà emballé - PP/PE', 'Déjà emballé - LDPE', 'PVC', 'Bouteille PET',]

# %%
table = df.loc[:,["Matériau d'emballage"]].isin(plastique_emballage)
len(table[table["Matériau d'emballage"]==True])/len(df)
# Out:
# 0.7067365873336022

# %% [markdown]
# 70% des produits présents dans la base sont emballés avec du plastique.

# %%
# on conserve que les produits contenant ces emballages
df_plastique = df[(df.loc[:,["Matériau d'emballage"]].isin(plastique_emballage)).squeeze()]


fig = px.icicle(df_plastique,
                path=[px.Constant("Matériau d'emballage plastique"), "Groupe d'aliment", "Sous-groupe d'aliment"],
                color_discrete_sequence=px.colors.qualitative.Vivid,
                title="Matériau d'emballage plastique : groupes et sous-groupes d'aliments concernés"
               )
fig.update_traces(root_color='lightgrey')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e1dc383c-902e-4634-8467-b1930fbd9dad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1dc383c-902e-4634-8467-b1930fbd9dad")) {                    Plotly.newPlot(                        "e1dc383c-902e-4634-8467-b1930fbd9dad",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Mat\u00e9riau d'emballage plastique/aides culinaires et ingr\u00e9dients divers/algues","Mat\u00e9riau d'emballage plastique/mati\u00e8res grasses/autres mati\u00e8res grasses","Mat\u00e9riau d'emballage plastique/viandes, \u0153ufs, poissons/autres produits \u00e0 base de viande","Mat\u00e9riau d'emballage plastique/mati\u00e8res grasses/beurres","Mat\u00e9riau d'emballage plastique/boissons/boissons sans alcool","Mat\u00e9riau d'emballage plastique/viandes, \u0153ufs, poissons/charcuteries","Mat\u00e9riau d'emballage plastique/produits sucr\u00e9s/chocolats et produits \u00e0 base de chocolat","Mat\u00e9riau d'emballage plastique/produits sucr\u00e9s/confiseries non chocolat\u00e9es","Mat\u00e9riau d'emballage plastique/lait et produits laitiers/cr\u00e8mes et sp\u00e9cialit\u00e9s \u00e0 base de cr\u00e8me","Mat\u00e9riau d'emballage plastique/produits c\u00e9r\u00e9aliers/c\u00e9r\u00e9ales de petit-d\u00e9jeuner et biscuits","Mat\u00e9riau d'emballage plastique/aliments infantiles/c\u00e9r\u00e9ales et biscuits infantiles","Mat\u00e9riau d'emballage plastique/aides culinaires et ingr\u00e9dients divers/denr\u00e9es destin\u00e9es \u00e0 une alimentation particuli\u00e8re","Mat\u00e9riau d'emballage plastique/glaces et sorbets/desserts glac\u00e9s","Mat\u00e9riau d'emballage plastique/aliments infantiles/desserts infantiles","Mat\u00e9riau d'emballage plastique/boissons/eaux","Mat\u00e9riau d'emballage plastique/produits c\u00e9r\u00e9aliers/farines et p\u00e2tes \u00e0 tarte","Mat\u00e9riau d'emballage plastique/entr\u00e9es et plats compos\u00e9s/feuillet\u00e9es et autres entr\u00e9es","Mat\u00e9riau d'emballage plastique/lait et produits laitiers/fromages","Mat\u00e9riau d'emballage plastique/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/fruits","Mat\u00e9riau d'emballage plastique/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/fruits \u00e0 coque et graines ol\u00e9agineuses","Mat\u00e9riau d'emballage plastique/glaces et sorbets/glaces","Mat\u00e9riau d'emballage plastique/produits c\u00e9r\u00e9aliers/g\u00e2teaux et p\u00e2tisseries","Mat\u00e9riau d'emballage plastique/aides culinaires et ingr\u00e9dients divers/herbes","Mat\u00e9riau d'emballage plastique/mati\u00e8res grasses/huiles et graisses v\u00e9g\u00e9tales","Mat\u00e9riau d'emballage plastique/aides culinaires et ingr\u00e9dients divers/ingr\u00e9dients divers","Mat\u00e9riau d'emballage plastique/lait et produits laitiers/laits","Mat\u00e9riau d'emballage plastique/aliments infantiles/laits et boissons infantiles","Mat\u00e9riau d'emballage plastique/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/l\u00e9gumes","Mat\u00e9riau d'emballage plastique/fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux/l\u00e9gumineuses","Mat\u00e9riau d'emballage plastique/mati\u00e8res grasses/margarines","Mat\u00e9riau d'emballage plastique/viandes, \u0153ufs, poissons/mollusques et crustac\u00e9s crus","Mat\u00e9riau d'emballage plastique/viandes, \u0153ufs, poissons/mollusques et crustac\u00e9s cuits","Mat\u00e9riau d'emballage plastique/produits c\u00e9r\u00e9aliers/pains et viennoiseries","Mat\u00e9riau d'emballage plastique/aliments infantiles/petits pots sal\u00e9s et plats infantiles","Mat\u00e9riau d'emballage plastiq ...

# %% [markdown]
# * Le groupe d'aliment "viandes, oeufs, poissons" sont les plus gros consommateurs d'emballage plastique, près du quart des plastiques.
# * Viennent ensuite les groupes d'aliment :
#  * "produits céréaliers" (> 10%)
#  * "lait et produits laitiers" (> 10%)
#  * " fruits, légumes, légumineuses et oléagineux" (> 10%).
# * Comme "viandes, oeufs, poissons" est le groupe d'aliment majoritaire, on peut s'attendre à une représentation importante de ce groupe parmi les produits utilsant des emballages plastiques.
# * Dans ce groupe "viandes, oeufs, poissons", quelle est la proportion d'emballages plastiques utilisés ?

# %%
# on conserve que le groupe 'viandes, œufs, poissons'
df_gp1_viandes = df[df.loc[:,"Groupe d'aliment"]=='viandes, œufs, poissons']
# proportion d'emballages plastiques utilisées dans ce groupe
len(df_gp1_viandes[df_gp1_viandes.loc[:,"Matériau d'emballage"].isin(plastique_emballage)])/len(df_gp1_viandes)
# Out:
# 0.9072327044025157

# %%
# liste des colonnes numériques, sans la target
col_float_no_target = df.drop('DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)', axis=1).select_dtypes(float).columns
col_float_no_target
# Out:
# Index(['Score unique EF (mPt/kg de produit)',
#        'Changement climatique (kg CO2 eq/kg de produit)',
#        'Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)',
#        'Rayonnements ionisants (kBq U-235 eq/kg de produit)',
#        'Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)',
#        'Particules (E-06 disease inc./kg de produit)',
#        'Acidification terrestre et eaux douces (mol H+ eq/kg de produit)',
#        'Eutrophisation terreste (mol N eq/kg de produit)',
#        'Eutrophisation eaux douces (E-03 kg P eq/kg de produit)',
#        'Eutrophisation marine (E-03 kg N eq/kg de produit)',
#        'Utilisation du sol (Pt/kg de produit)',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)',
#        'Épuisement des ressources eau (m3 depriv./kg de produit)',
#        'Épuisement des ressources énergétiques (MJ/kg de produit)',
#        'Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)'],
#       dtype='object')

# %%
# coefficient d'asymétrie

skew_list=[]
for col in col_float_no_target:
    skew_list.append((df[col].std()))
    
pd.DataFrame(skew_list, index=col_float_no_target)
# Out:
#                                                              0
# Score unique EF (mPt/kg de produit)                   0.885750
# Changement climatique (kg CO2 eq/kg de produit)       9.138402
# Appauvrissement de la couche d'ozone (E-06 kg C...    4.913065
# Rayonnements ionisants (kBq U-235 eq/kg de prod...    1.898260
# Formation photochimique d'ozone (E-03 kg NMVOC ...   42.971933
# Particules (E-06 disease inc./kg de produit)          0.886995
# Acidification terrestre et eaux douces (mol H+ ...    0.131431
# Eutrophisation terreste (mol N eq/kg de produit)      0.552303
# Eutrophisation eaux douces (E-03 kg P eq/kg de ...    2.567846
# Eutrophisation marine (E-03 kg N eq/kg de produit)   50.225766
# Utilisation du sol (Pt/kg de produit)               659.117300
# Écotoxicité pour écosystèmes aquatiques d'eau d...  149.496454
# Épuisement des ressources eau (m3 depriv./kg de...   17.266273
# Épuisement des ressources énergétiques (MJ/kg d...   56.788961
# Épuisement des ressources minéraux (E-06 kg Sb ...   19.029156

# %% [markdown]
# ## Analyse selon deux variables

# %%
# liste des variables type 'object'  
object_col = df.select_dtypes(object).columns

# afficher les box-plot
for col in object_col:
    fig = px.box(df, x=col, y=target, color=col, 
                 title="DQR en fonction de '{}'".format(col),
                 color_discrete_sequence=px.colors.qualitative.Vivid
                )
    fig.add_hline(y=3, line_width=1, line_color="red")
    fig.update_layout(boxgap=0, showlegend=False)
    fig.update_xaxes(tickangle=45)
    fig.update_traces(boxmean=True)
    iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="56ecaebc-748a-48b5-bc85-5cbead409e9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56ecaebc-748a-48b5-bc85-5cbead409e9a")) {                    Plotly.newPlot(                        "56ecaebc-748a-48b5-bc85-5cbead409e9a",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Groupe d'aliment=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","marker":{"color":"rgb(229, 134, 6)"},"name":"fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","notched":false,"offsetgroup":"fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","orientation":"v","showlegend":true,"x":["fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00e9gumineuses et ol\u00e9agineux","fruits, l\u00e9gumes, l\u00 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f6eb4a34-2e11-425a-a428-ecccc705066b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6eb4a34-2e11-425a-a428-ecccc705066b")) {                    Plotly.newPlot(                        "f6eb4a34-2e11-425a-a428-ecccc705066b",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Sous-groupe d'aliment=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"fruits","marker":{"color":"rgb(229, 134, 6)"},"name":"fruits","notched":false,"offsetgroup":"fruits","orientation":"v","showlegend":true,"x":["fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits","fruits"],"x0":" ","xaxis":"x","y":[2.46,2.46,2.46,2.44,2.2,2.64,2.93,2.93,2.93,2.93,2.68,2.46,2.96,3.12,3.12,2.92,2.2,3.01,2.46,2.7,2.68,3.01,1.98,1.98,1.98,1.98,2.96,2.99,3.04,2.9,2.96,2.14,2.14,2.25,3.12,3.58,3.01,3.35,3.01,3.12,2.36,3.01,2.92,3.01,2.79,3.12,3.12,2.1,2.1,2.1,2.1,2.46,2.79,2.79,2.81,2.57,3.12,3.58,3.12,2.79,3.29,2.9,2.68,3.12,2.46,2.68,2.55,2.55,2.25,2.64,2.84,2.57,2.57,3.01,3.01,3.01,2.26,2.26,2.07,2.14,2.03,2.14,2.53,2.68,2.57,2.64,1.98,2.46,2.46,2.46,2.75,3.12,3.61,2.43,3.12,2.92],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Sous-groupe d'aliment=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"produits \u00e0 base de poissons et produits de la mer","marker":{"color":"rgb(93, 105, 177)"},"name":"produits \u00e0 base de poissons et produits de la mer","notched":false,"offsetgroup":"produits \u00e0 base de poissons et produits de la mer","orientation":"v","showlegend":true,"x":["produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base de poissons et produits de la mer","produits \u00e0 base ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a8926617-31bf-49a1-9417-8dc8ad24f39c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8926617-31bf-49a1-9417-8dc8ad24f39c")) {                    Plotly.newPlot(                        "a8926617-31bf-49a1-9417-8dc8ad24f39c",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot au sirop l\u00e9ger, appertis\u00e9, \u00e9goutt\u00e9","marker":{"color":"rgb(229, 134, 6)"},"name":"Abricot au sirop l\u00e9ger, appertis\u00e9, \u00e9goutt\u00e9","notched":false,"offsetgroup":"Abricot au sirop l\u00e9ger, appertis\u00e9, \u00e9goutt\u00e9","orientation":"v","showlegend":true,"x":["Abricot au sirop l\u00e9ger, appertis\u00e9, \u00e9goutt\u00e9"],"x0":" ","xaxis":"x","y":[2.46],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot au sirop l\u00e9ger, appertis\u00e9, non \u00e9goutt\u00e9","marker":{"color":"rgb(93, 105, 177)"},"name":"Abricot au sirop l\u00e9ger, appertis\u00e9, non \u00e9goutt\u00e9","notched":false,"offsetgroup":"Abricot au sirop l\u00e9ger, appertis\u00e9, non \u00e9goutt\u00e9","orientation":"v","showlegend":true,"x":["Abricot au sirop l\u00e9ger, appertis\u00e9, non \u00e9goutt\u00e9"],"x0":" ","xaxis":"x","y":[2.46],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot au sirop, appertis\u00e9, \u00e9goutt\u00e9","marker":{"color":"rgb(82, 188, 163)"},"name":"Abricot au sirop, appertis\u00e9, \u00e9goutt\u00e9","notched":false,"offsetgroup":"Abricot au sirop, appertis\u00e9, \u00e9goutt\u00e9","orientation":"v","showlegend":true,"x":["Abricot au sirop, appertis\u00e9, \u00e9goutt\u00e9"],"x0":" ","xaxis":"x","y":[2.46],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot au sirop, appertis\u00e9, non \u00e9goutt\u00e9","marker":{"color":"rgb(153, 201, 69)"},"name":"Abricot au sirop, appertis\u00e9, non \u00e9goutt\u00e9","notched":false,"offsetgroup":"Abricot au sirop, appertis\u00e9, non \u00e9goutt\u00e9","orientation":"v","showlegend":true,"x":["Abricot au sirop, appertis\u00e9, non \u00e9goutt\u00e9"],"x0":" ","xaxis":"x","y":[2.44],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot, d\u00e9noyaut\u00e9, cru","marker":{"color":"rgb(204, 97, 176)"},"name":"Abricot, d\u00e9noyaut\u00e9, cru","notched":false,"offsetgroup":"Abricot, d\u00e9noyaut\u00e9, cru","orientation":"v","showlegend":true,"x":["Abricot, d\u00e9noyaut\u00e9, cru"],"x0":" ","xaxis":"x","y":[2.2],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Nom du Produit en Fran\u00e7ais=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Abricot, d\u00e9noyaut\u00e9, sec","marker":{"color":"rgb(36, 121, 108)"},"name":"Abricot, d\u00e9noyaut\u00e9, sec","notch ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="54c94430-4eb2-4ac1-a0ab-34963fbae010" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54c94430-4eb2-4ac1-a0ab-34963fbae010")) {                    Plotly.newPlot(                        "54c94430-4eb2-4ac1-a0ab-34963fbae010",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Saisonnalit\u00e9=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"mix de consommation FR","marker":{"color":"rgb(229, 134, 6)"},"name":"mix de consommation FR","notched":false,"offsetgroup":"mix de consommation FR","orientation":"v","showlegend":true,"x":["mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de consommation FR","mix de conso ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="66c3dcc0-b3ed-41da-8dd0-c308b0e21bf5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66c3dcc0-b3ed-41da-8dd0-c308b0e21bf5")) {                    Plotly.newPlot(                        "66c3dcc0-b3ed-41da-8dd0-c308b0e21bf5",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Livraison=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Ambiant (moyenne)","marker":{"color":"rgb(229, 134, 6)"},"name":"Ambiant (moyenne)","notched":false,"offsetgroup":"Ambiant (moyenne)","orientation":"v","showlegend":true,"x":["Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambiant (moyenne)","Ambia ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="81d02556-77da-44c7-b345-295953b58e61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81d02556-77da-44c7-b345-295953b58e61")) {                    Plotly.newPlot(                        "81d02556-77da-44c7-b345-295953b58e61",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Mat\u00e9riau d'emballage=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Acier","marker":{"color":"rgb(229, 134, 6)"},"name":"Acier","notched":false,"offsetgroup":"Acier","orientation":"v","showlegend":true,"x":["Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier","Acier"],"x0":" ","xaxis":"x","y":[2.46,2.46,2.46,2.44,2.93,2.93,2.93,2.93,2.78,2.78,2.59,2.63,2.93,2.89,2.55,2.5,2.82,2.97,3.53,3.1,2.97,3.53,3.53,3.07,2.21,3.0,3.01,2.9,1.9,3.0,3.28,3.29,3.08,3.08,3.23,2.78,3.08,3.08,3.08,2.84,3.63,4.02,4.02,4.02,4.02,2.7,3.13,3.37,3.37,3.37,3.21,3.22,2.53,2.1,2.1,2.1,2.1,2.49,2.86,2.78,2.78,2.78,2.78,2.78,2.78,2.78,2.5,2.32,2.65,2.32,2.55,2.55,2.38,2.89,2.93,2.84,3.29,3.8,3.66,3.08,3.05,1.97,2.65,2.78,3.17,3.57,2.78,3.17,3.1,2.78,2.78,2.78,2.78,2.78,2.78,2.68,2.59,3.1,3.38,2.89,2.78,3.11,2.95,3.11,3.03,3.11,2.99],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Mat\u00e9riau d'emballage=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"LPDE","marker":{"color":"rgb(93, 105, 177)"},"name":"LPDE","notched":false,"offsetgroup":"LPDE","orientation":"v","showlegend":true,"x":["LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE","LPDE" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a030e48c-777b-417a-9c5a-b1930c8de2cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a030e48c-777b-417a-9c5a-b1930c8de2cd")) {                    Plotly.newPlot(                        "a030e48c-777b-417a-9c5a-b1930c8de2cd",                        [{"alignmentgroup":"True","boxmean":true,"hovertemplate":"Pr\u00e9paration=%{x}<br>DQR - Note de qualit\u00e9 de la donn\u00e9e (1 excellente ; 5 tr\u00e8s faible)=%{y}<extra></extra>","legendgroup":"Pas de pr\u00e9paration ","marker":{"color":"rgb(229, 134, 6)"},"name":"Pas de pr\u00e9paration ","notched":false,"offsetgroup":"Pas de pr\u00e9paration ","orientation":"v","showlegend":true,"x":["Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de pr\u00e9paration ","Pas de ...
